# %%
# %pip install numpy pandas
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import numpy as np
#       2 import pandas as pd
#
# ModuleNotFoundError: No module named 'numpy'

# %%
num_students = 200

# %%
attendance = np.random.randint(50, 100, num_students)
cat_scores = np.random.randint(40, 100, num_students)
assignment_scores = np.random.randint(40, 100, num_students)
final_exam = np.random.randint(40, 100, num_students)

# %%
data = pd.DataFrame({
    "Attendance": attendance,
    "CAT_Score": cat_scores,
    "Assignment_Score": assignment_scores,
    "Final_Exam": final_exam
})

# %%
data.head()

# %%
data.to_csv("../data/student_performance.csv", index=False)
